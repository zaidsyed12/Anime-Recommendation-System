# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# **Data Loading**

# %%
anime = pd.read_csv("anime.csv")

# %% [markdown]
# **EDA**

# %%
print("Total # of samples in anime dataframe: ", len(anime.anime_id.unique()))
# Out:
# Total # of samples in anime dataframe:  12294

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
print(anime.shape)
# Out:
# (12294, 7)

# %% [markdown]
# **Data Preparation**

# %%
anime['genre'] = anime['genre'].str.split(', ') #spliting column's genre string values into lists of individual genres
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0             [Drama, Romance, School, Supernatural]  Movie        1    9.37
# 1  [Action, Adventure, Drama, Fantasy, Magic, Mil...     TV       64    9.26
# 2  [Action, Comedy, Historical, Parody, Samurai, ...     TV       51    9.25
# 3                                 [Sci-Fi, Thriller]     TV       24    9.17
# 4  [Action, Comedy, Historical, Parody, Samurai, ...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
anime['genre'] = anime['genre'].fillna('Unknown')
anime['type'] = anime['type'].fillna('Unknown')
anime['rating'] = anime['rating'].fillna(anime['rating'].mean())

# %%
anime.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
# Explode the 'genre' column, which contains lists of genres, into separate rows for each genre.
# converts a list in a single row into multiple rows, each containing one genre to get unique genre.
exploded_genres = anime.explode('genre')
unique_genres = exploded_genres['genre'].unique()
print("Total # of genres: ", len(unique_genres))
print("List of all unique genres: ", unique_genres)
# Out:
# Total # of genres:  44
# List of all unique genres:  ['Drama' 'Romance' 'School' 'Supernatural' 'Action' 'Adventure' 'Fantasy'
#  'Magic' 'Military' 'Shounen' 'Comedy' 'Historical' 'Parody' 'Samurai'
#  'Sci-Fi' 'Thriller' 'Sports' 'Super Power' 'Space' 'Slice of Life'
#  'Mecha' 'Music' 'Mystery' 'Seinen' 'Martial Arts' 'Vampire' 'Shoujo'
#  'Horror' 'Police' 'Psychological' 'Demons' 'Ecchi' 'Josei' 'Shounen Ai'
#  'Game' 'Dementia' 'Harem' 'Cars' 'Kids' 'Shoujo Ai' 'Unknown' 'Hentai'
#  'Yaoi' 'Yuri']

# %%
# For each row, join all genres (originally a list) into a single space-separated string
# Remove any spaces within individual genre names before joining and making it new column
anime['genre_str'] = anime['genre'].apply(lambda x: ' '.join(g.replace(' ', '') for g in x))
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                 [Drama, Romance, School, Supernatural]  Movie        1
# 1      [Action, Adventure, Drama, Fantasy, Magic, Mil...     TV       64
# 2      [Action, Comedy, Historical, Parody, Samurai, ...     TV       51
# 3                                     [Sci-Fi, Thriller]     TV       24
# 4      [Action, Comedy, Historical, Parody, Samurai, ...     TV       51
# ...                                                  ...    ...      ...
# 12289                                           [Hentai]    OVA        1
# 12290                                           [Hentai]    OVA        1
# 12291                                           [Hentai]    OVA        4
# 12292                                           [Hentai]    OVA        1
# 12293                                           [Hentai]  Movie        1
#
#        rating  members                                          genre_str
# 0        9.37   200630                  Drama Romance School Supernatural
# 1        9.26   793665  Action Adventure Drama Fantasy Magic Military ...
# 2        9.25   114262  Action Comedy Historical Parody Samurai Sci-Fi...
# 3        9.17   673572                                    Sci-Fi Thriller
# 4        9.16   151266  Action Comedy Historical Parody Samurai Sci-Fi...
# ...       ...      ...                                                ...
# 12289    4.15      211                                             Hentai
# 12290    4.28      183                                             Hentai
# 12291    4.88      219                                             Hentai
# 12292    4.98      175                                             Hentai
# 12293    5.46      142                                             Hentai
#
# [12294 rows x 8 columns]

# %%
# Count non-numeric values in the 'episodes' column
non_numeric_count = anime['episodes'].apply(lambda x: pd.to_numeric(x, errors='coerce')).isna().sum()

print(f"Number of non-numeric entries in the 'episodes' column: {non_numeric_count}")
# Out:
# Number of non-numeric entries in the 'episodes' column: 340

# %%
# Replace non-numeric values in 'episodes' with NaN
anime['episodes'] = anime['episodes'].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Fill NaN values with the median of the 'episodes' column
median_episodes = anime['episodes'].median()
anime['episodes'].fillna(median_episodes, inplace=True)

print(f"Replaced non-numeric entries with median value: {median_episodes}")
# Out:
# Replaced non-numeric entries with median value: 2.0

# %%
# Scale numerical columns (episodes, rating, members) to 0-1 range
scaler = MinMaxScaler()
anime[['episodes_scaled', 'rating_scaled', 'members_scaled']] = scaler.fit_transform(
    anime[['episodes', 'rating', 'members']]
)

# %% [markdown]
# ***Content-Based Filtering***

# %%
anime_data = anime
anime_data.sample(5)
# Out:
#       anime_id                                               name  \
# 9786     22849                                             Nyamen
# 7917     30367                       Lemon Home Animation Gekijou
# 4626      2729                                       X²: Double X
# 5892      9598  Haiyoru! Nyaruani: Remember My Love(craft-sensei)
# 7179     15653                                      Stay the Same
#
#                        genre     type  episodes  rating  members  \
# 9786                [Comedy]       TV      12.0    5.62      414
# 7917                [Comedy]  Special       2.0    4.65      254
# 4626  [Drama, Music, Shoujo]    Music       1.0    6.68     2976
# 5892        [Comedy, Sci-Fi]       TV      11.0    6.32    17934
# 7179           [Kids, Music]    Music       1.0    5.67      160
#
#                genre_str  episodes_scaled  rating_scaled  members_scaled
# 9786              Comedy         0.006054       0.474190        0.000403
# 7917              Comedy         0.000550       0.357743        0.000246
# 4626  Drama Music Shoujo         0.000000       0.601441        0.002930
# 5892       Comedy Sci-Fi         0.005504       0.558223        0.017683
# 7179          Kids Music         0.000000       0.480192        0.000153

# %%
# Categorical encoding for 'type' using one-hot encoding
type_one_hot = pd.get_dummies(anime_data['type'], prefix='type')

# %%
# TF-IDF vectorization for genres
tfv = TfidfVectorizer()

tfv.fit(anime_data['genre_str'])

tfv.get_feature_names_out()
# Out:
# array(['action', 'adventure', 'cars', 'comedy', 'dementia', 'demons',
#        'drama', 'ecchi', 'fantasy', 'fi', 'game', 'harem', 'hentai',
#        'historical', 'horror', 'josei', 'kids', 'magic', 'martialarts',
#        'mecha', 'military', 'music', 'mystery', 'parody', 'police',
#        'psychological', 'romance', 'samurai', 'school', 'sci', 'seinen',
#        'shoujo', 'shoujoai', 'shounen', 'shounenai', 'sliceoflife',
#        'space', 'sports', 'supernatural', 'superpower', 'thriller',
#        'vampire', 'yaoi', 'yuri'], dtype=object)

# %%
tfidf_matrix = tfv.fit_transform(anime_data['genre_str'])
tfidf_matrix.shape
# Out:
# (12294, 44)

# %%
features = np.hstack([
    tfidf_matrix.toarray(),                # Genre similarity
    type_one_hot.values,                  # Type similarity
    anime[['episodes_scaled',             # Episodes (scaled)
           'rating_scaled',               # Rating (scaled)
           'members_scaled']].values      # Members (scaled)
])

# %%
print(features.shape)
# Out:
# (12294, 54)

# %% [markdown]
# **Cosine Similarity**

# %%
# Compute cosine similarity between all items
cosine_sim = cosine_similarity(features)

# %%
# Create a DataFrame for similarity scores
cosine_sim_df = pd.DataFrame(cosine_sim, index=anime['name'], columns=anime['name'])
cosine_sim_df.head()
# Out:
# name                              Kimi no Na wa.  \
# name
# Kimi no Na wa.                          1.000000
# Fullmetal Alchemist: Brotherhood        0.362621
# Gintama°                                0.301120
# Steins;Gate                             0.314156
# Gintama&#039;                           0.300684
#
# name                              Fullmetal Alchemist: Brotherhood  Gintama°  \
# name
# Kimi no Na wa.                                            0.362621  0.301120
# Fullmetal Alchemist: Brotherhood                          1.000000  0.670999
# Gintama°                                                  0.670999  1.000000
# Steins;Gate                                               0.699430  0.695816
# Gintama&#039;                                             0.678177  0.999746
#
# name                              Steins;Gate  Gintama&#039;  \
# name
# Kimi no Na wa.                       0.314156       0.300684
# Fullmetal Alchemist: Brotherhood     0.699430       0.678177
# Gintama°                             0.695816       0.999746
# Steins;Gate                          1.000000       0.701827
# Gintama&#039;                        0.701827       1.000000
#
# name                              Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou  \
# name
# Kimi no Na wa.                                                             0.445800
# Fullmetal Alchemist: Brotherhood                                           0.699177
# Gintama°                                                                   0.711873
# Steins;Gate                                                                0.617965
# Gintama&#039;                                                              0.710881
#
# name                              Hunter x Hunter (2011)  \
# name
# Kimi no Na wa.                                  0.309954
# Fullmetal Alchemist: Brotherhood                0.798717
# Gintama°                                        0.722190
# Steins;Gate                                     0.669633
# Gintama&#039;                                   0.725407
#
# name                              Ginga Eiyuu Densetsu  \
# name
# Kimi no Na wa.                                0.350094
# Fullmetal Alchemist: Brotherhood              0.413199
# Gintama°                                      0.361992
# Steins;Gate                                   0.374876
# Gintama&#039;                                 0.360237
#
# name                              Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare  \
# name
# Kimi no Na wa.                                                             0.645871
# Fullmetal Alchemist: Brotherhood                                           0.337928
# Gintama°                                                                   0.645053
# Steins;Gate                                                                0.354972
# Gintama&#039;                                                              0.643695
#
# name                              Gintama&#039;: Enchousen  ...  \
# name                                                        ...
# Kimi no Na wa.                                    0.295392  ...
# Fullmetal Alchemist: Brotherhood                  0.662052  ...
# Gintama°                                          0.999705  ...
# Steins;Gate                                       0.688140  ...
# Gintama&#039;                                     0.999078  ...
#
# name                              Super Erotic Anime  Taimanin Asagi 3  \
# name
# Kimi no Na wa.                              0.124817          0.312699
# Fullmetal Alchemist: Brotherhood            0.112804          0.185527
# Gintama°                                    0.123996          0.203863
# Steins;Gate                                 0.114701          0.188639
# Gintama&#039;                               0.122741          0.201805
#
# name                              Teleclub no Himitsu  Tenshi no Habataki Jun  \
# name
# Kimi no Na wa.                               0.134115                0.119703
# Fullmetal Alchemist: Brotherhood             0.121211                0.108194
# Gintama°                                     0.133232                0.118907
# Steins;Gate                                  0.123249                0.110014
# Gintama&#039;                                0.131884                0.117705
#
# name                              The Satisfaction  \
# name
# Kimi no Na wa.                            0.121411
# Fullmetal Alchemist: Brotherhood          0.109730
# Gintama°                                  0.120605
# Steins;Gate                               0.111577
# Gintama&#039;                             0.119385
#
# name                              Toushindai My Lover: Minami tai Mecha-Minami  \
# name
# Kimi no Na wa.                                                        0.111960
# Fullmetal Alchemist: Brotherhood                                      0.101201
# Gintama°                                                              0.111215
# Steins;Gate                                                           0.102902
# Gintama&#039;                                                         0.110091
#
# name                              Under World  Violence Gekiga David no Hoshi  \
# name
# Kimi no Na wa.                       0.117558                        0.142879
# Fullmetal Alchemist: Brotherhood     0.106253                        0.129158
# Gintama°                             0.116777                        0.141948
# Steins;Gate                          0.108040                        0.131318
# Gintama&#039;                        0.115596                        0.140513
#
# name                              Violence Gekiga Shin David no Hoshi: Inma Densetsu  \
# name
# Kimi no Na wa.                                                             0.147005
# Fullmetal Alchemist: Brotherhood                                           0.132856
# Gintama°                                                                   0.146030
# Steins;Gate                                                                0.135094
# Gintama&#039;                                                              0.144553
#
# name                              Yasuji no Pornorama: Yacchimae!!
# name
# Kimi no Na wa.                                            0.562146
# Fullmetal Alchemist: Brotherhood                          0.150404
# Gintama°                                                  0.165333
# Steins;Gate                                               0.152939
# Gintama&#039;                                             0.163660
#
# [5 rows x 12294 columns]

# %% [markdown]
# **Recommendation Function**

# %%
def anime_recommendations(nama_anime, similarity_data, items, k):    # Get the similarities of the input anime with others
    closest = similarity_data[nama_anime].sort_values(ascending=False)

    # Drop the input anime itself from recommendations
    closest = closest.drop(nama_anime, errors='ignore')

    # Merge with the anime data to get more details
    closest_animes = pd.DataFrame(closest).reset_index()  # Reset index to keep anime names as a column
    closest_animes.columns = ['Recommended Anime', 'Similarity']  # Rename columns for clarity

    # Merge with the items dataframe based on the 'Recommended Anime' column
    recommendations = closest_animes.merge(items[['name', 'genre', 'type', 'episodes', 'rating', 'members']],
                                           left_on='Recommended Anime', right_on='name', how='left')

    return recommendations[['Recommended Anime', 'genre', 'type', 'episodes', 'rating', 'members']].head(k)

# %% [markdown]
# **To know exact name of anime**

# %%
anime_input = input("Input anime name: ")
anime_data[anime_data['name'].str.contains(anime_input, case=False)]
# Out:
# Input anime name: naruto
#       anime_id                                               name  \
# 486      28755                           Boruto: Naruto the Movie
# 615       1735                                 Naruto: Shippuuden
# 719      16870                         The Last: Naruto the Movie
# 784      13667         Naruto: Shippuuden Movie 6 - Road to Ninja
# 841         20                                             Naruto
# 1103     32365  Boruto: Naruto the Movie - Naruto ga Hokage ni...
# 1237     10589          Naruto: Shippuuden Movie 5 - Blood Prison
# 1343     10075                                        Naruto x UT
# 1472      8246        Naruto: Shippuuden Movie 4 - The Lost Tower
# 1573      6325  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...
# 1827      2472                         Naruto: Shippuuden Movie 1
# 1828      4437                Naruto: Shippuuden Movie 2 - Kizuna
# 2374      4134  Naruto Shippuuden: Shippuu! &quot;Konoha Gakue...
# 2416     10686  Naruto: Honoo no Chuunin Shiken! Naruto vs. Ko...
# 2457     12979   Naruto SD: Rock Lee no Seishun Full-Power Ninden
# 2458     19511               Naruto Shippuuden: Sunny Side Battle
# 2756       442  Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shin...
# 2997     10659  Naruto Soyokazeden Movie: Naruto to Mashin to ...
# 3449       936  Naruto Movie 2: Dai Gekitotsu! Maboroshi no Ch...
# 3529      2248  Naruto: Dai Katsugeki!! Yuki Hime Shinobu Houj...
# 3560      2144  Naruto Movie 3: Dai Koufun! Mikazuki Jima no A...
# 3561      7367                            Naruto: The Cross Roads
# 3838      1074  Naruto Narutimate Hero 3: Tsuini Gekitotsu! Jo...
# 3984       594  Naruto: Takigakure no Shitou - Ore ga Eiyuu Da...
# 5111       761          Naruto: Akaki Yotsuba no Clover wo Sagase
#
#                                                   genre     type  episodes  \
# 486   [Action, Comedy, Martial Arts, Shounen, Super ...    Movie       1.0
# 615   [Action, Comedy, Martial Arts, Shounen, Super ...       TV       2.0
# 719   [Action, Martial Arts, Romance, Shounen, Super...    Movie       1.0
# 784   [Action, Adventure, Martial Arts, Shounen, Sup...    Movie       1.0
# 841   [Action, Comedy, Martial Arts, Shounen, Super ...       TV     220.0
# 1103  [Action, Comedy, Martial Arts, Shounen, Super ...  Special       1.0
# 1237  [Action, Adventure, Martial Arts, Mystery, Sho...    Movie       1.0
# 1343  [Action, Comedy, Martial Arts, Shounen, Super ...      OVA       1.0
# 1472  [Action, Comedy, Martial Arts, Shounen, Super ...    Movie       1.0
# 1573  [Action, Comedy, Martial Arts, Shounen, Super ...    Movie       1.0
# 1827      [Action, Adventure, Comedy, Fantasy, Shounen]    Movie       1.0
# 1828      [Action, Martial Arts, Shounen, Supernatural]    Movie       1.0
# 2374                                           [Comedy]  Special       1.0
# 2416  [Action, Adventure, Martial Arts, Shounen, Sup...    Movie       1.0
# 2457                           [Action, Comedy, Parody]       TV      51.0
# 2458  [Action, Comedy, Martial Arts, Shounen, Super ...  Special       1.0
# 2756  [Adventure, Comedy, Drama, Historical, Shounen...    Movie       1.0
# 2997  [Action, Comedy, Martial Arts, Shounen, Super ...    Movie       1.0
# 3449  [Adventure, Comedy, Drama, Fantasy, Shounen, S...    Movie       1.0
# 3529  [Action, Comedy, Fantasy, Martial Arts, Shoune...  Special       1.0
# 3560                                [Action, Adventure]    Movie       1.0
# 3561               [Action, Adventure, Comedy, Shounen]  Special       1.0
# 3838                 [Adventure, Comedy, Game, Shounen]      OVA       1.0
# 3984  [Action, Adventure, Comedy, Shounen, Super Power]  Special       1.0
# 5111                       [Adventure, Comedy, Shounen]  Special       1.0
#
#       rating  members                                          genre_str  \
# 486     8.03    74690       Action Comedy MartialArts Shounen SuperPower
# 615     7.94   533578       Action Comedy MartialArts Shounen SuperPower
# 719     7.88    85013      Action MartialArts Romance Shounen SuperPower
# 784     7.84    87369    Action Adventure MartialArts Shounen SuperPower
# 841     7.81   683297       Action Comedy MartialArts Shounen SuperPower
# 1103    7.68    16868       Action Comedy MartialArts Shounen SuperPower
# 1237    7.62    75660  Action Adventure MartialArts Mystery Shounen S...
# 1343    7.58    23465       Action Comedy MartialArts Shounen SuperPower
# 1472    7.53    84527       Action Comedy MartialArts Shounen SuperPower
# 1573    7.50    83515       Action Comedy MartialArts Shounen SuperPower
# 1827    7.43   108170            Action Adventure Comedy Fantasy Shounen
# 1828    7.43    97818            Action MartialArts Shounen Supernatural
# 2374    7.28    34056                                             Comedy
# 2416    7.27    30378    Action Adventure MartialArts Shounen SuperPower
# 2457    7.26    29989                               Action Comedy Parody
# 2458    7.26    13014       Action Comedy MartialArts Shounen SuperPower
# 2756    7.17   120571  Adventure Comedy Drama Historical Shounen Supe...
# 2997    7.11    25174       Action Comedy MartialArts Shounen SuperPower
# 3449    6.99    97308  Adventure Comedy Drama Fantasy Shounen Superna...
# 3529    6.96    47988   Action Comedy Fantasy MartialArts Shounen Sports
# 3560    6.95    91526                                   Action Adventure
# 3561    6.95    22131                    Action Adventure Comedy Shounen
# 3838    6.87    45188                      Adventure Comedy Game Shounen
# 3984    6.83    52264         Action Adventure Comedy Shounen SuperPower
# 5111    6.55    47587                           Adventure Comedy Shounen
#
#       episodes_scaled  rating_scaled  members_scaled
# 486          0.000000       0.763505        0.073660
# 615          0.000550       0.752701        0.526252
# 719          0.000000       0.745498        0.083842
# 784          0.000000       0.740696        0.086165
# 841          0.120528       0.737095        0.673916
# 1103         0.000000       0.721489        0.016632
# 1237         0.000000       0.714286        0.074617
# 1343         0.000000       0.709484        0.023138
# 1472         0.000000       0.703481        0.083362
# 1573         0.000000       0.699880        0.082364
# 1827         0.000000       0.691477        0.106681
# 1828         0.000000       0.691477        0.096471
# 2374         0.000000       0.673469        0.033584
# 2416         0.000000       0.672269        0.029956
# 2457         0.027518       0.671068        0.029573
# 2458         0.000000       0.671068        0.012831
# 2756         0.000000       0.660264        0.118912
# 2997         0.000000       0.653061        0.024824
# 3449         0.000000       0.638655        0.095968
# 3529         0.000000       0.635054        0.047325
# 3560         0.000000       0.633854        0.090265
# 3561         0.000000       0.633854        0.021822
# 3838         0.000000       0.624250        0.044563
# 3984         0.000000       0.619448        0.051542
# 5111         0.000000       0.585834        0.046929

# %% [markdown]
# **Content-Based Recommendation on inputing an Anime name:**

# %%
# Get top-N Recommendations based from anime input list
anime_recommendations('Naruto: Shippuuden', cosine_sim_df, anime_data, k=10)
# Out:
#         Recommended Anime                                              genre  \
# 0                  Naruto  [Action, Comedy, Martial Arts, Shounen, Super ...
# 1           Dragon Ball Z  [Action, Adventure, Comedy, Fantasy, Martial A...
# 2             Dragon Ball  [Adventure, Comedy, Fantasy, Martial Arts, Sho...
# 3         Dragon Ball Kai  [Action, Adventure, Comedy, Fantasy, Martial A...
# 4       Dragon Ball Super  [Action, Adventure, Comedy, Fantasy, Martial A...
# 5          Rekka no Honoo  [Action, Adventure, Martial Arts, Shounen, Sup...
# 6  Dragon Ball Kai (2014)  [Action, Adventure, Comedy, Fantasy, Martial A...
# 7  Kurokami The Animation                [Action, Martial Arts, Super Power]
# 8            Project ARMS                [Action, Martial Arts, Super Power]
# 9  Katekyo Hitman Reborn!             [Action, Comedy, Shounen, Super Power]
#
#   type  episodes  rating  members
# 0   TV     220.0    7.81   683297
# 1   TV     291.0    8.32   375662
# 2   TV     153.0    8.16   316102
# 3   TV      97.0    7.95   116832
# 4   TV       2.0    7.40   111443
# 5   TV      42.0    7.44    35258
# 6   TV      61.0    8.01    42666
# 7   TV      23.0    7.29    72750
# 8   TV      26.0    7.15     6903
# 9   TV     203.0    8.37   258103
